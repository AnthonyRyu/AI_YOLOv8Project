# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.9/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %cd {HOME}
# !yolo task=segment mode=predict model=yolov8n-seg.pt source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# ...
# 100% 6.73M/6.73M [00:00<00:00, 193MB/s]
#
# 2023-11-20 13:26:50.811719: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-20 13:26:50.811781: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-20 13:26:50.811833: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-20 13:26:51.847906: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd {HOME}
Image(filename = 'runs/segment/predict/dog.jpeg', height=600)
# Out:
# /content

# %%
rm -rf /content/datasets

# %%
# !mkdir {HOME}/datasets

# %%
# %cd /content/datasets
# !pwd
# !ls -al
# Out:
# /content/datasets
# /content/datasets
# total 12
# drwxr-xr-x 2 root root 4096 Nov 20 13:27 .
# drwxr-xr-x 1 root root 4096 Nov 20 13:27 ..

# %%
# !unzip /content/drive/MyDrive/butterfly_data.zip
# Out:
# Archive:  /content/drive/MyDrive/butterfly_data.zip
#  extracting: train/images/butterfly (1).png
#   inflating: train/images/butterfly (10).png
#   inflating: train/images/butterfly (100).png
#   inflating: train/images/butterfly (101).png
#  extracting: train/images/butterfly (102).png
#  extracting: train/images/butterfly (103).png
#  extracting: train/images/butterfly (104).png
#   inflating: train/images/butterfly (105).png
#  extracting: train/images/butterfly (106).png
#   inflating: train/images/butterfly (107).png
#  extracting: train/images/butterfly (108).png
#   inflating: train/images/butterfly (109).png
#  extracting: train/images/butterfly (11).png
#  extracting: train/images/butterfly (110).png
#  extracting: train/images/butterfly (111).png
#   inflating: train/images/butterfly (112).png
#  extracting: train/images/butterfly (113).png
#  extracting: train/images/butterfly (114).png
#   inflating: train/images/butterfly (115).png
# ...

# %%
# %cd {HOME}
# !yolo task=segment mode=train model=yolov8n-seg.pt data=/content/datasets/butterfly_data.yaml epochs=300 imgsz=640 plots=True patience=0
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /content
# /bin/bash: line 1: yolo: command not found
